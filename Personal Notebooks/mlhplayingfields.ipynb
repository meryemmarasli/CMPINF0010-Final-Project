# %% [markdown]
# ## The Playing Fields of Pittsburgh

# %% [markdown]
# First, I intialized the variables playing_fields and playing_fields_names for my dataset.

# %%
#load pandas
import pandas as pd
# %matplotlib inline

#load data from WPRDC
playing_fields = pd.read_csv("https://data.wprdc.org/datastore/dump/6af89346-b971-41d5-af09-49cfdb4dfe23", index_col = "neighborhood", parse_dates = True)
playing_fields_names = pd.read_csv("https://data.wprdc.org/datastore/dump/6af89346-b971-41d5-af09-49cfdb4dfe23", index_col = "id", parse_dates = True)

# %% [markdown]
# I utilized the len() function, groupby operation, and the count() function in order to calculate the number of playing fields within the neighborhoods of Pittsburgh.

# %%
number_of_playing_fields = len(playing_fields.groupby("neighborhood").count())
print("The city of Pittsburgh has a total of " + str(number_of_playing_fields) + " playing fields in its neighborhoods.")
# Out:
# The city of Pittsburgh has a total of 51 playing fields in its neighborhoods.

# %% [markdown]
# Here I made the decision to place each neighborhood into a list and reuse the groupby function to later create a dataframe and loop through that list.

# %%
#neighborhood_names = playing_fields.groupby("neighborhood").count()
neighborhood_names = []
for i in playing_fields_names["neighborhood"]:
    if i not in neighborhood_names:
        neighborhood_names.append(i)
    else:
        continue
neighborhood_names = sorted(neighborhood_names)
print(neighborhood_names)

playing_fields.groupby("neighborhood").count()
# Out:
# ['Allegheny Center', 'Allentown', 'Arlington', 'Banksville', 'Bedford Dwellings', 'Beechview', 'Beltzhoover', 'Brighton Heights', 'Brookline', 'Carrick', 'Central Lawrenceville', 'Central Oakland', 'Crafton Heights', 'East Hills', 'East Liberty', 'Elliott', 'Fineview', 'Garfield', 'Greenfield', 'Hazelwood', 'Highland Park', 'Homewood South', 'Larimer', 'Lincoln Place', 'Lincoln-Lemington-Belmar', 'Lower Lawrenceville', 'Manchester', 'Marshall-Shadeland', 'Morningside', 'Mount Washington', 'Oakwood', 'Perry North', 'Perry South', 'Polish Hill', 'Regent Square', 'Shadyside', 'Sheraden', 'South Oakland', 'South Side Flats', 'South Side Slopes', 'Spring Garden', 'Spring Hill-City View', 'Squirrel Hill North', 'Squirrel Hill South', 'Stanton Heights', 'Terrace Village', 'Troy Hill', 'Upper Lawrenceville', 'West End', 'Westwood', 'Windgap']
#                           id  name  has_lights  park  field_usage  goal_post  \
# neighborhood
# Allegheny Center           2     2           2     2            2          2
# Allentown                  1     1           1     1            1          1
# Arlington                  1     1           1     1            1          1
# Banksville                 2     2           2     2            2          2
# Bedford Dwellings          2     2           2     2            2          2
# Beechview                  3     3           3     3            3          3
# Beltzhoover                3     3           3     3            3          3
# Brighton Heights           7     7           7     7            7          7
# Brookline                  6     6           6     6            6          6
# Carrick                    5     5           5     5            5          5
# Central Lawrenceville      2     2           2     2            2          2
# Central Oakland            1     1           1     1            1          1
# Crafton Heights            2     2           2     2            2          2
# East Hills                 1     1           1     1            1          1
# East Liberty               1     1           1     1            1          1
# Elliott                    2     2           2     2            2          2
# Fineview                   1     1           1     1            1          1
# Garfield                   1     1           1     1            1          1
# Greenfield                 2     2           2     2            2          2
# Hazelwood                  4     4           4     4            4          4
# Highland Park              4     4           4     4            4          4
# Homewood South             1     1           1     1            1          1
# Larimer                    1     1           1     1            1          1
# Lincoln Place              1     1           1     1            1          1
# Lincoln-Lemington-Belmar   2     2           2     2            2          2
# Lower Lawrenceville        4     4           4     4            4          4
# Manchester                 2     2           2     2            2          2
# Marshall-Shadeland         1     1           1     1            1          1
# Morningside                3     3           3     3            3          3
# Mount Washington           3     3           3     3            3          3
# Oakwood                    1     1           1     1            1          1
# Perry North                2     2           2     2            2          2
# Perry South                1     1           1     1            1          1
# Polish Hill                1     1           1     1            1          1
# Regent Square              2     2           2     2            2          2
# Shadyside                  3     3           3     3            3          3
# Sheraden                   3     3           3     3            3          3
# South Oakland              2     2           2     2            2          2
# South Side Flats           2     2           2     2            2          2
# South Side Slopes          6     6           6     6            6          6
# Spring Garden              1     1           1     1            1          1
# Spring Hill-City View      2     2           2     2            2          2
# Squirrel Hill North        1     1           1     1            1          1
# Squirrel Hill South        5     5           5     5            5          5
# Stanton Heights            1     1           1     1            1          1
# Terrace Village            1     1           1     1            1          1
# Troy Hill                  3     3           3     3            3          3
# Upper Lawrenceville        1     1           1     1            1          1
# West End                   1     1           1     1            1          1
# Westwood                   2     2           2     2            2          2
# Windgap                    1     1           1     1            1          1
#
#                           infield_type  left_field_distance  \
# neighborhood
# Allegheny Center                     2                    2
# Allentown                            0                    0
# Arlington                            1                    1
# Banksville                           2                    2
# Bedford Dwellings                    2                    2
# Beechview                            2                    2
# Beltzhoover                          3                    3
# Brighton Heights                     7                    7
# Brookline                            5                    5
# Carrick                              4                    4
# Central Lawrenceville                2                    2
# Central Oakland                      1                    1
# Crafton Heights                      2                    2
# East Hills                           1                    1
# East Liberty                         1                    1
# Elliott                              2                    2
# Fineview                             1                    1
# Garfield                             0                    0
# Greenfield                           2                    2
# Hazelwood                            3                    3
# Highland Park                        4                    4
# Homewood South                       1                    1
# Larimer                              0                    0
# Lincoln Place                        1                    1
# Lincoln-Lemington-Belmar             1                    1
# Lower Lawrenceville                  3                    3
# Manchester                           1                    1
# Marshall-Shadeland                   1                    1
# Morningside                          3                    3
# Mount Washington                     3                    3
# Oakwood                              1                    1
# Perry North                          1                    1
# Perry South                          0                    0
# Polish Hill                          1                    1
# Regent Square                        2                    2
# Shadyside                            3                    3
# Sheraden                             3                    3
# South Oakland                        1                    1
# South Side Flats                     2                    2
# South Side Slopes                    5                    5
# Spring Garden                        1                    1
# Spring Hill-City View                2                    2
# Squirrel Hill North                  1                    1
# Squirrel Hill South                  1                    1
# Stanton Heights                      1                    1
# Terrace Village                      1                    1
# Troy Hill                            3                    3
# Upper Lawrenceville                  1                    1
# West End                             1                    0
# Westwood                             2                    2
# Windgap                              1                    1
#
#                           center_field_distance  right_field_distance  \
# neighborhood
# Allegheny Center                              2                     2
# Allentown                                     0                     0
# Arlington                                     1                     1
# Banksville                                    2                     2
# Bedford Dwellings                             2                     2
# Beechview                                     2                     2
# Beltzhoover                                   3                     3
# Brighton Heights                              7                     7
# Brookline                                     5                     5
# Carrick                                       4                     4
# Central Lawrenceville                         2                     2
# Central Oakland                               1                     1
# Crafton Heights                               2                     2
# East Hills                                    1                     1
# East Liberty                                  1                     1
# Elliott                                       2                     2
# Fineview                                      1                     1
# Garfield                                      0                     0
# Greenfield                                    2                     2
# Hazelwood                                     3                     3
# Highland Park                                 4                     4
# Homewood South                                1                     1
# Larimer                                       0                     0
# Lincoln Place                                 1                     1
# Lincoln-Lemington-Belmar                      1                     1
# Lower Lawrenceville                           3                     3
# Manchester                                    1                     1
# Marshall-Shadeland                            1                     1
# Morningside                                   3                     3
# Mount Washington                              3                     3
# Oakwood                                       1                     1
# Perry North                                   1                     1
# Perry South                                   0                     0
# Polish Hill                                   1                     1
# Regent Square                                 2                     2
# Shadyside                                     3                     3
# Sheraden                                      3                     3
# South Oakland                                 1                     1
# South Side Flats                              2                     2
# South Side Slopes                             5                     5
# Spring Garden                                 1                     1
# Spring Hill-City View                         2                     2
# Squirrel Hill North                           1                     1
# Squirrel Hill South                           1                     1
# Stanton Heights                               1                     1
# Terrace Village                               1                     1
# Troy Hill                                     3                     3
# Upper Lawrenceville                           1                     1
# West End                                      0                     0
# Westwood                                      2                     2
# Windgap                                       1                     1
#
#                           backstop  council_district  ward  tract  \
# neighborhood
# Allegheny Center                 0                 2     2      2
# Allentown                        0                 1     1      1
# Arlington                        0                 1     1      1
# Banksville                       0                 2     2      2
# Bedford Dwellings                0                 2     2      2
# Beechview                        0                 3     3      3
# Beltzhoover                      0                 3     3      3
# Brighton Heights                 0                 7     7      7
# Brookline                        0                 6     6      6
# Carrick                          0                 5     5      5
# Central Lawrenceville            0                 2     2      2
# Central Oakland                  0                 1     1      1
# Crafton Heights                  0                 2     2      2
# East Hills                       0                 1     1      1
# East Liberty                     0                 1     1      1
# Elliott                          0                 2     2      2
# Fineview                         0                 1     1      1
# Garfield                         0                 1     1      1
# Greenfield                       0                 2     2      2
# Hazelwood                        0                 4     4      4
# Highland Park                    0                 4     4      4
# Homewood South                   0                 1     1      1
# Larimer                          0                 1     1      1
# Lincoln Place                    0                 1     1      1
# Lincoln-Lemington-Belmar         0                 2     2      2
# Lower Lawrenceville              0                 4     4      4
# Manchester                       0                 2     2      2
# Marshall-Shadeland               0                 1     1      1
# Morningside                      0                 3     3      3
# Mount Washington                 0                 3     3      3
# Oakwood                          0                 1     1      1
# Perry North                      0                 2     2      2
# Perry South                      0                 1     1      1
# Polish Hill                      0                 1     1      1
# Regent Square                    0                 2     2      2
# Shadyside                        0                 3     3      3
# Sheraden                         0                 3     3      3
# South Oakland                    0                 2     2      2
# South Side Flats                 0                 2     2      2
# South Side Slopes                0                 6     6      6
# Spring Garden                    0                 1     1      1
# Spring Hill-City View            0                 2     2      2
# Squirrel Hill North              0                 1     1      1
# Squirrel Hill South              0                 5     5      5
# Stanton Heights                  0                 1     1      1
# Terrace Village                  0                 1     1      1
# Troy Hill                        0                 3     3      3
# Upper Lawrenceville              0                 1     1      1
# West End                         0                 1     1      1
# Westwood                         0                 2     2      2
# Windgap                          0                 1     1      1
#
#                           public_works_division  pli_division  police_zone  \
# neighborhood
# Allegheny Center                              2             2            2
# Allentown                                     1             1            1
# Arlington                                     1             1            1
# Banksville                                    2             2            2
# Bedford Dwellings                             2             2            2
# Beechview                                     3             3            3
# Beltzhoover                                   3             3            3
# Brighton Heights                              7             7            7
# Brookline                                     6             6            6
# Carrick                                       5             5            5
# Central Lawrenceville                         2             2            2
# Central Oakland                               1             1            1
# Crafton Heights                               2             2            2
# East Hills                                    1             1            1
# East Liberty                                  1             1            1
# Elliott                                       2             2            2
# Fineview                                      1             1            1
# Garfield                                      1             1            1
# Greenfield                                    2             2            2
# Hazelwood                                     4             4            4
# Highland Park                                 4             4            4
# Homewood South                                1             1            1
# Larimer                                       1             1            1
# Lincoln Place                                 1             1            1
# Lincoln-Lemington-Belmar                      2             2            2
# Lower Lawrenceville                           4             4            4
# Manchester                                    2             2            2
# Marshall-Shadeland                            1             1            1
# Morningside                                   3             3            3
# Mount Washington                              3             3            3
# Oakwood                                       1             1            1
# Perry North                                   2             2            2
# Perry South                                   1             1            1
# Polish Hill                                   1             1            1
# Regent Square                                 2             2            2
# Shadyside                                     3             3            3
# Sheraden                                      3             3            3
# South Oakland                                 2             2            2
# South Side Flats                              2             2            2
# South Side Slopes                             6             6            6
# Spring Garden                                 1             1            1
# Spring Hill-City View                         2             2            2
# Squirrel Hill North                           1             1            1
# Squirrel Hill South                           5             5            5
# Stanton Heights                               1             1            1
# Terrace Village                               1             1            1
# Troy Hill                                     3             3            3
# Upper Lawrenceville                           1             1            1
# West End                                      1             1            1
# Westwood                                      2             2            2
# Windgap                                       1             1            1
#
#                           fire_zone  latitude  longitude
# neighborhood
# Allegheny Center                  2         2          2
# Allentown                         1         1          1
# Arlington                         1         1          1
# Banksville                        2         2          2
# Bedford Dwellings                 2         2          2
# Beechview                         3         3          3
# Beltzhoover                       3         3          3
# Brighton Heights                  7         7          7
# Brookline                         6         6          6
# Carrick                           5         5          5
# Central Lawrenceville             2         2          2
# Central Oakland                   1         1          1
# Crafton Heights                   2         2          2
# East Hills                        1         1          1
# East Liberty                      1         1          1
# Elliott                           2         2          2
# Fineview                          1         1          1
# Garfield                          1         1          1
# Greenfield                        2         2          2
# Hazelwood                         4         4          4
# Highland Park                     4         4          4
# Homewood South                    1         1          1
# Larimer                           1         1          1
# Lincoln Place                     1         1          1
# Lincoln-Lemington-Belmar          2         2          2
# Lower Lawrenceville               4         4          4
# Manchester                        2         2          2
# Marshall-Shadeland                1         1          1
# Morningside                       3         3          3
# Mount Washington                  3         3          3
# Oakwood                           1         1          1
# Perry North                       2         2          2
# Perry South                       1         1          1
# Polish Hill                       1         1          1
# Regent Square                     2         2          2
# Shadyside                         3         3          3
# Sheraden                          3         3          3
# South Oakland                     2         2          2
# South Side Flats                  2         2          2
# South Side Slopes                 6         6          6
# Spring Garden                     1         1          1
# Spring Hill-City View             2         2          2
# Squirrel Hill North               1         1          1
# Squirrel Hill South               5         5          5
# Stanton Heights                   1         1          1
# Terrace Village                   1         1          1
# Troy Hill                         3         3          3
# Upper Lawrenceville               1         1          1
# West End                          1         1          1
# Westwood                          2         2          2
# Windgap                           1         1          1

# %% [markdown]
# Next, I found the number of playing fields in the neighborhoods of Pittsburgh, as well as the mean number of playing fields per neighborhood.

# %%
pitts_playing_fields = 0 
for i in range(51):
    pitts_playing_fields = pitts_playing_fields + playing_fields_per_neighborhood["amount of playing fields"][i]

mean = pitts_playing_fields / 51

print("The total number of playing fields in the city of Pittsburgh is " + str(pitts_playing_fields) + ".")
print("The mean number of playing fields per neighborhood in the city of Pittsburgh is " + str(mean) + ".")
# Out:
# The total number of playing fields in the city of Pittsburgh is 113.
# The mean number of playing fields per neighborhood in the city of Pittsburgh is 2.215686274509804.

# %% [markdown]
# Finally, I used a for loop to calculate the number of neighborhooods with a total amount of playing fields greater than the mean.

# %%
for i in range(51):
    if playing_fields_per_neighborhood["amount of playing fields"][i] > 2:
        print(playing_fields_per_neighborhood["neighborhood"][i])
# Out:
# Beechview
# Beltzhoover
# Brighton Heights
# Brookline
# Carrick
# Hazelwood
# Highland Park
# Lower Lawrenceville
# Morningside
# Mount Washington
# Shadyside
# Sheraden
# South Side Slopes
# Squirrel Hill South
# Troy Hill

# %%
top15_neighborhoods = pd.DataFrame({"top 15 neighborhoods": ["Beechview", "Beltzhoover", "Brighton Heights", "Brookline", "Carrick",
                                                            "Hazelwood", "Highland Park", "Lower Lawrenceville", "Morningside",
                                                            "Mount Washington", "Shadyside", "Sheraden", "South Side Slopes", 
                                                            "Squirrel Hill South", "Troy Hill"], 
                                    "amount of playing fields": [3, 3, 7, 6, 5, 4, 4, 4, 3, 3, 3, 3, 6, 5, 3]})
top15_neighborhoods_bargraph = top15_neighborhoods.plot.bar(x = "top 15 neighborhoods", legend = False, figsize = (20, 5))
plt.ylabel("amount of playing fields")
plt.title("Top 15 Neighborhoods for Playing Fields")
# Out:
# Text(0.5, 1.0, 'Top 15 Neighborhoods for Playing Fields')

# %% [markdown]
# ## The Results
# The Neighborhood that has the greatest amount of playing fields is Brighton Heights. It leads Pittsburgh with seven total.
# Brookline and South Side Slopes each follow with six playing fields, which is the second most.
# Carrick and Stanton Heights each have five, which is the third most.
# Additionally, ten other neighborhoods had three playing fields (which was greater than the mean).
